# %% [markdown]
# # Case study On CreditCard Dataset:
#
# **Implement the following steps:**
#
# Steps:
# 1. Import different required library
# 2. Check the version of the Library
# 3. Go for different observation like Info, description
# 4. Check null Values
# 5. Check duplicate values
# 6. Filter for different condition - come up with insights from the dataset, basic plot, distribution plots
# 7. Use a histogram to plot different columns

# %% [markdown]
# #### Importing different libraries

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import math
import os
import inspect

# %% [markdown]
# #### Checking the versions of the Libraries

# %%
print(f'Numpy version : Numpy {np.__version__}')
print(f'Pandas version : Pandas {np.__version__}')
print(f'Matplotlib version : Matplotlib {np.__version__}')
print(f'Seaborn version : Seaborn {np.__version__}')
# Out:
# Numpy version : Numpy 1.16.5
# Pandas version : Pandas 1.16.5
# Matplotlib version : Matplotlib 1.16.5
# Seaborn version : Seaborn 1.16.5

# %% [markdown]
# #### Importing the Dataset

# %%
os.chdir(r'C:\Users\shail\Downloads')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\shail\\Downloads'

# %%
df = pd.read_csv('creditcard.csv')

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %% [markdown]
# #### Different observations on the Dataset

# %%
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
df['Class'].value_counts(normalize = True)
# Out:
# '0'    0.998273
# '1'    0.001727
# Name: Class, dtype: float64

# %%
inspect.getfullargspec(pd.value_counts)
# Out:
# FullArgSpec(args=['values', 'sort', 'ascending', 'normalize', 'bins', 'dropna'], varargs=None, varkw=None, defaults=(True, False, False, None, True), kwonlyargs=[], kwonlydefaults=None, annotations={})

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9       V10       V11       V12       V13       V14  \
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941
# 284803  1.058415  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802
# 284804  3.031260 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119
# 284805  0.623708 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886
# 284806 -0.649617  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513
#
#              V13       V14       V15       V16       V17       V18       V19  \
# ...

# %%
df['Amount'].max()
# Out:
# 25691.16

# %%
df['Amount'].describe()
# Out:
# count    284807.000000
# mean         88.349619
# std         250.120109
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.165000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
def indices_of_outliers(x):
    q1, q3 = np.percentile(x,[25,75])
    iqr = q3 - q1
    lower_bound = q1 - (iqr * 1.5)
    upper_bound = q3 + (iqr * 1.5)
    return np.where((x > upper_bound) | (x < lower_bound))

# %%
list(indices_of_outliers(df['Amount'])[0])
# Out:
# [2,
#  20,
#  51,
#  64,
#  85,
#  89,
#  134,
#  140,
#  142,
#  147,
#  149,
#  150,
#  164,
#  174,
#  189,
#  206,
#  212,
#  227,
#  235,
#  240,
#  249,
#  257,
#  259,
#  281,
#  296,
#  344,
#  373,
#  392,
#  396,
#  421,
#  429,
#  433,
#  456,
#  466,
#  468,
#  472,
#  478,
#  513,
#  519,
#  521,
#  535,
#  550,
#  572,
#  573,
#  593,
#  623,
#  632,
#  633,
#  647,
#  651,
#  654,
#  665,
#  666,
#  706,
#  727,
#  732,
#  736,
#  740,
#  747,
#  778,
#  782,
#  785,
#  823,
#  843,
#  847,
#  865,
#  906,
#  909,
#  948,
#  954,
#  964,
#  975,
#  977,
#  991,
#  1006,
#  1009,
#  1027,
#  1031,
#  1038,
#  1044,
#  1064,
#  1073,
#  1081,
#  1089,
#  1096,
#  1102,
#  1108,
#  1114,
#  1154,
#  1184,
#  1204,
#  1208,
#  1221,
#  1226,
#  1240,
#  1245,
#  1248,
#  1268,
#  1281,
#  1298,
#  1300,
#  1301,
#  1319,
#  1333,
#  1346,
#  1359,
#  1371,
#  1374,
#  1380,
#  1386,
#  1388,
#  1404,
#  1419,
#  1421,
#  1425,
#  1426,
#  1446,
#  1453,
#  1485,
#  1488,
# ...

# %%
len(list(indices_of_outliers(df['Amount'])[0]))
# Out:
# 31904

# %%
df[df.index.isin(list(indices_of_outliers(df['Amount'])[0]))]
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 2            1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 20          16.0  0.694885 -1.361819  1.029221  0.834159 -1.191209  1.309109
# 51          36.0 -1.004929 -0.985978 -0.038039  3.710061 -6.631951  5.122103
# 64          42.0 -0.522666  1.009923  0.276470  1.475289 -0.707013  0.355243
# 85          55.0 -4.575093 -4.429184  3.402585  0.903915  3.002224 -0.491078
# ...          ...       ...       ...       ...       ...       ...       ...
# 284735  172727.0 -1.661169 -0.565425  0.294268 -1.549156 -2.301359  2.365956
# 284748  172738.0  1.634178 -0.486939 -1.975967  0.495364  0.263635 -0.713049
# 284753  172743.0  1.465737 -0.618047 -2.851391  1.425282  0.893893 -0.958325
# 284757  172745.0 -1.757643 -0.982659  1.091540 -1.409539 -0.662159  0.046930
# 284806  172792.0 -0.533413 -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
# ...

# %%
len(df)
# Out:
# 284807

# %%
df[df.index.isin(list(indices_of_outliers(df['Amount'])[0]))]['Class'].value_counts(normalize = True)
# Out:
# '0'    0.997148
# '1'    0.002852
# Name: Class, dtype: float64

# %%
df['Class'].value_counts(normalize = True)
# Out:
# '0'    0.998273
# '1'    0.001727
# Name: Class, dtype: float64

# %%
plt.figure(figsize=(14,8))
plt.boxplot(df['Amount']);

# %%
df = df.drop(df[df['Amount']>20000].index.values[0])
df.reset_index(drop = True, inplace = True)

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284801  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284802  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284803  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284804  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284805  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# ...

# %%
df['Time'].max()
# Out:
# 172792.0

# %%
172792/(60*60)
# Out:
# 47.99777777777778

# %%
df.shape
# Out:
# (284806, 31)

# %%
df.Class.unique()
# Out:
# array(["'0'", "'1'"], dtype=object)

# %%
df.Time.dtype
# Out:
# dtype('float64')

# %%
print(f'Rows : {df.shape[0]}')
print(f'Columns : {df.shape[1]}')
# Out:
# Rows : 284806
# Columns : 31

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284806 entries, 0 to 284805
# Data columns (total 31 columns):
# Time      284806 non-null float64
# V1        284806 non-null float64
# V2        284806 non-null float64
# V3        284806 non-null float64
# V4        284806 non-null float64
# V5        284806 non-null float64
# V6        284806 non-null float64
# V7        284806 non-null float64
# V8        284806 non-null float64
# V9        284806 non-null float64
# V10       284806 non-null float64
# V11       284806 non-null float64
# V12       284806 non-null float64
# V13       284806 non-null float64
# V14       284806 non-null float64
# V15       284806 non-null float64
# V16       284806 non-null float64
# V17       284806 non-null float64
# V18       284806 non-null float64
# V19       284806 non-null float64
# V20       284806 non-null float64
# V21       284806 non-null float64
# V22       284806 non-null float64
# V23       284806 non-null float64
# ...

# %%
df[['Amount', 'Class', 'Time']].describe()
# Out:
#               Amount           Time
# count  284806.000000  284806.000000
# mean       88.259724   94813.608934
# std       245.476460   47488.040941
# min         0.000000       0.000000
# 25%         5.600000   54201.250000
# 50%        22.000000   84691.500000
# 75%        77.160000  139320.000000
# max     19656.530000  172792.000000

# %%
print(df['Time'].min() / (60*60))
print(df['Time'].max() / (60*60))
# Out:
# 0.0
# 47.99777777777778

# %%
print(df.isnull().any().sum(), '\n')
print(df.isnull().sum(), '\n')
print(df.isnull().values.any())
# Out:
# 0
#
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64
#
# False

# %% [markdown]
# #### Checking duplicates values in the Dataset

# %%
print(len(df.drop_duplicates()))
print(len(df[df.duplicated()]))
# Out:
# 283725
# 1081

# %% [markdown]
# #### Insights from the dataset

# %%
plt.figure(figsize=(20,20))
sns.distplot(df['Amount']);

# %%
plt.figure(figsize=(20, 20))
sns.scatterplot(df.Time, df.Amount);

# %% [markdown]
# #### Histogram plots for different columns

# %%
plt.hist(df.Amount);
